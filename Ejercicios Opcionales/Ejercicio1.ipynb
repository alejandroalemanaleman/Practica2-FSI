# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
#Filtra las regiones que sean mayores de un cierto tamaño.

# Cargar la imagen
image = cv2.imread("fot1.png")

# Convertir a escala de grises
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Binarización de la imagen
_, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)

# Encontrar contornos en la imagen binarizada
contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filtrar contornos por área
min_contour_area = 700
filtered_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_contour_area]

# Crear una imagen filtrada en negro
filtered_image = np.zeros_like(image)

# Rellenar los contornos filtrados con blanco en la imagen filtrada
cv2.fillPoly(filtered_image, filtered_contours, (255, 255, 255))

# Visualización con Matplotlib
plt.figure(figsize=(10, 5))

# Imagen original
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

# Imagen filtrada
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(filtered_image, cv2.COLOR_BGR2RGB))
plt.title('Filtered Image')

# Mostrar la figura con los dos subgráficos
plt.show()
